# %% [markdown]
# ## SVAT tutorial

# %%
import subprocess

subprocess.Popen("python svat.py", shell=True)
# Out:
# <Popen: returncode: None args: 'python svat.py'>
# Importing core modules
#  Using computational backend numpy on cpu
#  Runtime settings are now locked
#
# Use available forcing.
#
# Running model setup
#  Writing output for diagnostic "collect" every 1.0 days
#  Writing output for diagnostic "rate" every 1.0 days
#  Writing output for diagnostic "maximum" every 1.0 days
# Setup done
#
# IMPORTANT: Always check your logger output for warnings
#  on diverging solutions. The occurence of warnings may
#  require an post-evaluation of the accuracy of
#  the numerical solution (e.g. calculate
#  standard deviation of dS_num_error).
#
#
# Starting calculation for 1.0 years
#  Current iteration: 0     (0.00/1.00y |  0.0% | 0.00s/(model year) | 0.0s left)
#  Current iteration: 1     (0.00/1.00y |  0.0% | 1.891/(model year) | 1.91 left)
#  Current iteration: 2     (0.00/1.00y |  0.0% | 1.421/(model year) | 1.41 left)
# ...
